# %% [markdown]
# # Import Lib

# %%
import pandas as pd
import matplotlib.pyplot as  plt
import numpy as np

# %matplotlib inline

import os

path = os.getcwd()

print(path)
# Out:
# C:\Users\gauravb\Documents\GitHub\mydevcodePUBLIC_new\Python\Jupyter\Prima

# %% [markdown]
# ## Folder Location

# %%
print(path)
# Out:
# C:\Users\gauravb\Documents\GitHub\mydevcodePUBLIC_new\Python\Jupyter\Prima

# %% [markdown]
# ## Load the Data

# %%
df = pd.read_csv("pima-data.csv")

# %% [markdown]
# ### df.shape will display number of rows, Col

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head(5) # Number 5 will tell how many lines to return
# Out:
#    num_prg   pl_glu_con   bp   tcps   ins   bmi    ped   age   cv
# 0        6          148   72     35     0  33.6  0.627    50    1
# 1        1           85   66     29     0  26.6  0.351    31    0
# 2        8          183   64      0     0  23.3  0.672    32    1
# 3        1           89   66     23    94  28.1  0.167    21    0
# 4        0          137   40     35   168  43.1  2.288    33    1

# %% [markdown]
# ## Check Tail

# %%
df.tail(500)
# Out:
#      num_prg   pl_glu_con   bp   tcps   ins   bmi    ped   age   cv
# 268        0          102   52      0     0  25.1  0.078    21    0
# 269        2          146    0      0     0  27.5  0.240    28    1
# 270       10          101   86     37     0  45.6  1.136    38    1
# 271        2          108   62     32    56  25.2  0.128    21    0
# 272        3          122   78      0     0  23.0  0.254    40    0
# ..       ...          ...  ...    ...   ...   ...    ...   ...  ...
# 763       10          101   76     48   180  32.9  0.171    63    0
# 764        2          122   70     27     0  36.8  0.340    27    0
# 765        5          121   72     23   112  26.2  0.245    30    0
# 766        1          126   60      0     0  30.1  0.349    47    1
# 767        1           93   70     31     0  30.4  0.315    23    0
#
# [500 rows x 9 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
def plot_corr(df, size=11):
    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size,size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)

# %%
plot_corr(df)

# %%
df.corr()
# Out:
#               num_prg   pl_glu_con        bp      tcps       ins       bmi  \
# num_prg      1.000000     0.129459  0.141282 -0.081672 -0.073535  0.017683
#  pl_glu_con  0.129459     1.000000  0.152590  0.057328  0.331357  0.221071
#  bp          0.141282     0.152590  1.000000  0.207371  0.088933  0.281805
#  tcps       -0.081672     0.057328  0.207371  1.000000  0.436783  0.392573
#  ins        -0.073535     0.331357  0.088933  0.436783  1.000000  0.197859
#  bmi         0.017683     0.221071  0.281805  0.392573  0.197859  1.000000
#  ped        -0.033523     0.137337  0.041265  0.183928  0.185071  0.140647
#  age         0.544341     0.263514  0.239528 -0.113970 -0.042163  0.036242
#  cv          0.221898     0.466581  0.065068  0.074752  0.130548  0.292695
#
#                   ped       age        cv
# num_prg     -0.033523  0.544341  0.221898
#  pl_glu_con  0.137337  0.263514  0.466581
#  bp          0.041265  0.239528  0.065068
#  tcps        0.183928 -0.113970  0.074752
#  ins         0.185071 -0.042163  0.130548
#  bmi         0.140647  0.036242  0.292695
#  ped         1.000000  0.033561  0.173844
#  age         0.033561  1.000000  0.238356
#  cv          0.173844  0.238356  1.000000

# %%
df.head()
# Out:
#    num_prg   pl_glu_con   bp   tcps   ins   bmi    ped   age   cv
# 0        6          148   72     35     0  33.6  0.627    50    1
# 1        1           85   66     29     0  26.6  0.351    31    0
# 2        8          183   64      0     0  23.3  0.672    32    1
# 3        1           89   66     23    94  28.1  0.167    21    0
# 4        0          137   40     35   168  43.1  2.288    33    1
